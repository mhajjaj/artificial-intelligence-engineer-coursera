# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# <h1>Test Sigmoid, Tanh, and Relu Activations Functions on the MNIST Dataset</h1>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to apply different activation functions on the MNIST dataset.</li></ul>

# %% [markdown]
# <h2>Table of Contents</h2>
# <p>In this lab, you will test sigmoid, tanh, and relu activation functions on the MNIST dataset.</p>
#
# <ul>
#     <li><a href="#Model">Neural Network Module and Training Function</a></li>
#     <li><a href="#Makeup_Data">Make Some Data</a></li>
#     <li><a href="#Train">Define Several Neural Network, Criterion Function, and Optimizer</a></li>
#     <li><a href="#Test">Test Sigmoid, Tanh, and Relu</a></li>
#     <li><a href="#Result">Analyze Results</a></li>
# </ul>
# <p></p>
# Estimated Time Needed: <strong>25 min</strong>
# </div>
#
# <hr>

# %% [markdown]
# <h2>Preparation</h2>

# %% [markdown]
# We'll need the following libraries

# %%
# %%time
# %pip install pandas numpy matplotlib
# %pip install torch==2.8.0+cpu torchvision==0.23.0+cpu torchaudio==2.8.0+cpu \
    --index-url https://download.pytorch.org/whl/cpu
# Out:
# Requirement already satisfied: pandas in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (3.0.2)
# Requirement already satisfied: numpy in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (2.4.4)
# Requirement already satisfied: matplotlib in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch==2.8.0+cpu in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (2.8.0+cpu)
# Requirement already satisfied: torchvision==0.23.0+cpu in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (0.23.0+cpu)
# Requirement already satisfied: torchaudio==2.8.0+cpu in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (2.8.0+cpu)
# Requirement already satisfied: filelock in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from torch==2.8.0+cpu) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from torch==2.8.0+cpu) (4.15.0)
# Requirement already satisfied: setuptools in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from torch==2.8.0+cpu) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from torch==2.8.0+cpu) (1.14.0)
# Requirement already satisfied: networkx in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from torch==2.8.0+cpu) (3.6.1)
# Requirement already satisfied: jinja2 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from torch==2.8.0+cpu) (3.1.6)
# Requirement already satisfied: fsspec in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from torch==2.8.0+cpu) (2026.2.0)
# Requirement already satisfied: numpy in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from torchvision==0.23.0+cpu) (2.4.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from torchvision==0.23.0+cpu) (12.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch==2.8.0+cpu) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/hajjaj/Desktop/RUTILEA/coursera/artificial-intelligence-engineer-coursera/.venv/lib/python3.12/site-packages (from jinja2->torch==2.8.0+cpu) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# CPU times: user 57.8 ms, sys: 17.7 ms, total: 75.6 ms
# Wall time: 2.21 s

# %%
# Uncomment the following line to install the torchvision library
# !mamba install -y torchvision

# Import the libraries we need for this lab

import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as dsets

import matplotlib.pylab as plt
import numpy as np

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Model">Neural Network Module and Training Function</h2>

# %% [markdown]
# Define the neural network module or class using the sigmoid activation function:

# %%
# Build the model with sigmoid function

class Net(nn.Module):
    
    # Constructor
    def __init__(self, D_in, H, D_out):
        super(Net, self).__init__()
        self.linear1 = nn.Linear(D_in, H)
        self.linear2 = nn.Linear(H, D_out)
    
    # Prediction
    def forward(self, x):
        x = torch.sigmoid(self.linear1(x))  
        x = self.linear2(x)
        return x

# %% [markdown]
# Define the neural network module or class using the Tanh activation function:

# %%
# Build the model with Tanh function

class NetTanh(nn.Module):

    # Constructor
    def __init__(self, D_in, H, D_out):
        super(NetTanh, self).__init__()
        self.linear1 = nn.Linear(D_in, H)
        self.linear2 = nn.Linear(H, D_out)

    # Prediction
    def forward(self, x):
        x = torch.tanh(self.linear1(x))
        x = self.linear2(x)
        return x

# %% [markdown]
# Define the neural network module or class using the Relu activation function:

# %%
# Build the model with Relu function

class NetRelu(nn.Module):

    # Constructor
    def __init__(self, D_in, H, D_out):
        super(NetRelu, self).__init__()
        self.linear1 = nn.Linear(D_in, H)
        self.linear2 = nn.Linear(H, D_out)

    # Prediction
    def forward(self, x):
        x = torch.relu(self.linear1(x))
        x = self.linear2(x)
        return x

# %% [markdown]
# Define a function to train the model. In this case, the function returns a Python dictionary to store the training loss for each iteration  and accuracy on the validation data.

# %%
# Define the function for training the model

def train(model, criterion, train_loader, validation_loader, optimizer, epochs = 100):
    i = 0
    useful_stuff = {'training_loss':[], 'validation_accuracy':[]}  

    for epoch in range(epochs):
        for i, (x, y) in enumerate(train_loader):
            optimizer.zero_grad()
            z = model(x.view(-1, 28 * 28))
            loss = criterion(z, y)
            loss.backward()
            optimizer.step()
            useful_stuff['training_loss'].append(loss.item())

        correct = 0
        for x, y in validation_loader:
            z = model(x.view(-1, 28 * 28))
            _, label=torch.max(z, 1)
            correct += (label == y).sum().item()
        accuracy = 100 * (correct / len(validation_dataset))
        useful_stuff['validation_accuracy'].append(accuracy)

    return useful_stuff

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Makeup_Data">Make Some Data</h2>

# %% [markdown]
# Load the training dataset by setting the parameters <code>train</code> to <code>True</code> and convert it to a tensor by placing a transform object in the argument <code>transform</code>.

# %%
# Create the training dataset

train_dataset = dsets.MNIST(root='./data', train=True, download=True, transform=transforms.ToTensor())

# %% [markdown]
# Load the testing dataset by setting the parameter <code>train</code> to <code>False</code> and convert it to a tensor by placing a transform object in the argument <code>transform</code>.

# %%
# Create the validation  dataset

validation_dataset = dsets.MNIST(root='./data', train=False, download=True, transform=transforms.ToTensor())

# %% [markdown]
# Create the criterion function:

# %%
# Create the criterion function

criterion = nn.CrossEntropyLoss()

# %% [markdown]
# Create the training-data loader and the validation-data loader object:

# %%
# Create the training data loader and validation data loader object

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=2000, shuffle=True)
validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=5000, shuffle=False)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Train">Define the Neural Network, Criterion Function, Optimizer, and Train the Model</h2>

# %% [markdown]
# Create the criterion function:

# %%
# Create the criterion function

criterion = nn.CrossEntropyLoss()

# %% [markdown]
# Create the model with 100 hidden neurons:

# %%
# Create the model object

input_dim = 28 * 28
hidden_dim = 100
output_dim = 10

model = Net(input_dim, hidden_dim, output_dim)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Test">Test Sigmoid, Tanh, and Relu</h2>

# %% [markdown]
# Train the network by using the sigmoid activations function:

# %%
# Train a model with sigmoid function

learning_rate = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
training_results = train(model, criterion, train_loader, validation_loader, optimizer, epochs=30)

# %% [markdown]
# Train the network by using the Tanh activations function:

# %%
# Train a model with Tanh function

model_Tanh = NetTanh(input_dim, hidden_dim, output_dim)
optimizer = torch.optim.SGD(model_Tanh.parameters(), lr=learning_rate)
training_results_tanch = train(model_Tanh, criterion, train_loader, validation_loader, optimizer, epochs=30)

# %% [markdown]
# Train the network by using the Relu activations function:

# %%
# Train a model with Relu function

modelRelu = NetRelu(input_dim, hidden_dim, output_dim)
optimizer = torch.optim.SGD(modelRelu.parameters(), lr=learning_rate)
training_results_relu = train(modelRelu, criterion, train_loader, validation_loader, optimizer, epochs=30)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Result">Analyze Results</h2>

# %% [markdown]
# Compare the training loss for each activation:

# %%
# Compare the training loss

plt.plot(training_results_tanch['training_loss'], label='tanh')
plt.plot(training_results['training_loss'], label='sigmoid')
plt.plot(training_results_relu['training_loss'], label='relu')
plt.ylabel('loss')
plt.title('training loss iterations')
plt.legend()
plt.show()

# %% [markdown]
# Compare the validation loss for each model:

# %%
# Compare the validation loss

plt.plot(training_results_tanch['validation_accuracy'], label='tanh')
plt.plot(training_results['validation_accuracy'], label='sigmoid')
plt.plot(training_results_relu['validation_accuracy'], label='relu') 
plt.ylabel('validation accuracy')
plt.xlabel('epochs ')
plt.legend()
plt.show()

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# ## Which activation function performed best ?

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Other contributors: <a href="https://www.linkedin.com/in/michelleccarey/">Michelle Carey</a>, <a href="https://www.linkedin.com/in/jiahui-mavis-zhou-a4537814a">Mavis Zhou</a>

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-23  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
